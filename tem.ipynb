# %%
import pandas as pd
df = pd.read_excel("app/data/output.xlsx")
df.head()
# Out:
#                                          description  \
# 0           ซื้อขายระบบผลิตไฟฟ้าจากพลังงานแสงอาทิตย์
# 1  เงินส่วนหนึ่งของราคาที่ดินซื้อขาย Lotus’s stor...
# 2  Local: CAPEX PO (AD+AM+IM) and Tools for the p...
# 3  Offshore: CAPEX PO (AD+AM+IM) for the period o...
# 4  BNA3,4,5_งานเพิ่ม-ลด งานMEP[IW] Project constr...
#
#                                            category  \
# 0                                   Energy Projects
# 1                                         Contracts
# 2  Other Computer & Information Technology Services
# 3  Other Computer & Information Technology Services
# 4                             Construction Services
#
#                               spec_pred                          item_pred  \
# 0                                   NaN         ระบบผลิตไฟฟ้าจากแสงอาทิตย์
# 1  item ค่าใช้จ่ายที่เกี่ยวข้องกับสัญญา         เงินส่วนหนึ่งของราคาที่ดิน
# 2             item บริการไอที|period 1m  IT Operation Model Implementation
# ...

# %%
df.shape
# Out:
# (541638, 9)

# %%
temp = df[['description', 'category', 'spec_pred']]
input_test_df = temp[100:150]
input_test_df.head()
# Out:
#                                            description  \
# 100             Fryer Machine Model 11000/1050 Thermal
# 101  (MT)[FMST371] Imp. Escalator Yr.2025 6 store (...
# 102  MKB-Operation Cost Charge Actual Volume  Varia...
# 103  (YS)   CS_"Main Building"_New Store HP_Srirach...
# 104  Land Purchase Super.6464 Nongkhae   (TD.10406 ...
#
#                                               category  \
# 100                               Electric Deep Fryers
# 101  Escalator Installation Or Maintenance Or Repai...
# 102   Other Computer & Information Technology Services
# 103                                    Roofing Service
# 104                                 Warehouse Services
#
#                                              spec_pred
# 100  brand -|capacity -|item หม้อทอดไฟฟ้า|model -|n...
# 101                        item บํารุงรักษาบันไดเลื่อน
# 102                         item ค่าเอเจนซี่|period 1m
# 103                                     item งานหลังคา
# ...

# %%
input_test_df.to_csv("input_test.csv", index=False)

# %%
temp.to_csv("full_input_test.csv", index=False)
